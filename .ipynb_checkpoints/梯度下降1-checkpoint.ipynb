# %%
import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv(os.path.join(os.getcwd(), 'Datas', 'Data-Cleaning-2.csv'))
data.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>symboling</th>
#       <th>normalized-losses</th>
#       <th>engine-size</th>
#       <th>bore</th>
#       <th>stroke</th>
#       <th>compression-ratio</th>
#       <th>horsepower</th>
#       <th>peak-rpm</th>
#       <th>highway-mpg</th>
#       <th>volume</th>
#       <th>...</th>
#       <th>num-of-cylinders_three</th>
#       <th>num-of-cylinders_twelve</th>
#       <th>fuel-system_1bbl</th>
#       <th>fuel-system_2bbl</th>
#       <th>fuel-system_idi</th>
#       <th>fuel-system_mfi</th>
#       <th>fuel-system_mpfi</th>
#       <th>fuel-system_spdi</th>
#       <th>fuel-system_spfi</th>
# ...

# %%
target = data['price']
features = data.drop('price', axis=1)

# %%
# 这里开始划分数据
seed = 123
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=seed)

# %% [markdown]
# 然后就要开始做梯度的公式了，先看一下目标函数<br>
# $J_{(\theta)}=\frac{1}{2m}[(x^0_0*\theta_0+x^0_1*\theta_1+x^0_2*\theta_2+....+x^0_j*\theta_j)+(x^1_0*\theta_0+x^1_1*\theta_1+x^1_2*\theta_2+....+x^1_j*\theta_j)
# +(x^2_0*\theta_0+x^2_1*\theta_1+x^2_2*\theta_2+....+x^2_j*\theta_j)+......\qquad+(x^m_0*\theta_0+x^m_1*\theta_1+x^m_2*\theta_2+....+x^m_j*\theta_j)]\\\quad=\frac{1}{2m}[(X^0*\theta^T)+(X^1*\theta^T)+(X^2*\theta^T)+......+(X^m*\theta^T)]$
